# %% [markdown]
# <a href="https://colab.research.google.com/github/manishyerram89/Object-Detection/blob/main/IrisDet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.2/107.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/classroom3
# Out:
# /content/drive/MyDrive/classroom3

# %%
# !ls
# Out:
# bus.jpg  dataNeg  data.yaml  runs  yolov8n.pt  yolov8s.pt

# %%
# %cd /content/drive/MyDrive/classroom3

# !yolo task=detect mode=train model=yolov8s.pt data= data.yaml epochs=20 imgsz=224 plots=True
# Out:
# /content/drive/MyDrive/classroom3
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU
# ...

# %%
Image(filename='/content/drive/MyDrive/classroom3/runs/detect/train9/confusion_matrix.png', width=600)

# %%
Image(filename='runs/detect/train9/results.png', width=600)

# %%
Image(filename='runs/detect/train9/val_batch0_pred.jpg', width=600)

# %%
# !yolo task=detect mode=val model=runs/detect/train9/weights/best.pt data=data.yaml
# Out:
# 2023-07-06 04:06:45.355003: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-06 04:06:47.149800: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/drive/MyDrive/classroom3/dataNeg/val/labels.cache... 43 images, 20 backgrounds, 0 corrupt: 100% 43/43 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:04<00:00,  1.65s/it]
#                    all         43         23      0.999          1      0.995      0.868
# ...
